# %%
from ImageClassification import SimpleImageClassifier

# %%
test1 = SimpleImageClassifier('images/Sports_Ball')
# Out:
# Removing bad or corrupted images...
# Images removed due to invalid type: 0
# Images removed due to issues opening image: 0
# Total removed images: 0
#
# Baseball: 156 images
# Football: 145 images
# Soccer: 134 images
# Tennis: 149 images
#
# Found 584 files belonging to 4 classes.
# 19 image batche(s) of size 32 created

# %%
test1.get_label_count()
# Out:
# 4

# %%
test1.draw_labels()

# %%
scaled_data = test1.scale_data()

# %%
train, val, test = test1.split_data(scaled_data)
# Out:
# Total Batches: 19
# Train Batch Count: 15
# Validation Batch Count: 2
# Test Batch Size: 2

# %%
model = test1.create_default_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 256)               7373056
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# ...
# Total params: 7,381,492
# Trainable params: 7,381,492
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = test1.train_and_evaluate(model, train, val, test, epochs=15)
# Out:
# Epoch 1/15
# 15/15 [==============================] - 7s 370ms/step - loss: 1.6100 - accuracy: 0.4167 - val_loss: 1.0132 - val_accuracy: 0.4844
# Epoch 2/15
# 15/15 [==============================] - 6s 303ms/step - loss: 0.9104 - accuracy: 0.6167 - val_loss: 0.5795 - val_accuracy: 0.8125
# Epoch 3/15
# 15/15 [==============================] - 6s 313ms/step - loss: 0.6435 - accuracy: 0.7812 - val_loss: 0.6071 - val_accuracy: 0.7656
# Epoch 4/15
# 15/15 [==============================] - 5s 301ms/step - loss: 0.4416 - accuracy: 0.8604 - val_loss: 0.3018 - val_accuracy: 0.8906
# Epoch 5/15
# 15/15 [==============================] - 6s 362ms/step - loss: 0.3108 - accuracy: 0.9104 - val_loss: 0.1442 - val_accuracy: 0.9688
# Epoch 6/15
# 15/15 [==============================] - 6s 317ms/step - loss: 0.2260 - accuracy: 0.9500 - val_loss: 0.0961 - val_accuracy: 1.0000
# Epoch 7/15
# ...

# %%
test1.evaluate_model(model, test)

# %%
test1.test_single_image(model, 'test_images\Sports_Ball')
