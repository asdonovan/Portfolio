# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
sns.set()

# %%
raw_data = pd.read_csv('CarPrice_Assignment.csv')
pd.set_option('display.max_rows', None)

raw_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# 205 observations
# 26 features
raw_data.shape
# Out:
# (205, 26)

# %%
raw_data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
# Plotting barchart of price data
plt.hist(raw_data['price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
raw_data['price'].sort_values(ascending=False)[:10] # View top 10 highest prices
# Out:
# 74     45400.0
# 16     41315.0
# 73     40960.0
# 128    37028.0
# 17     36880.0
# 49     36000.0
# 48     35550.0
# 72     35056.0
# 71     34184.0
# 127    34028.0
# Name: price, dtype: float64

# %%
df = raw_data.copy()
df = df[df['price'] < 40000] # Removes top 3 outliers
df.shape
# Out:
# (202, 26)

# %%
# Plot updated price barchart
plt.hist(df['price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Data Preprocessing - Dropping car_ID

# %%
df_drop_id = df.drop(['car_ID'], axis=1) # Remove ID column since its not useful information
print(df_drop_id.shape)
df_drop_id.head()
# Out:
# (202, 25)
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %% [markdown]
# ## Data Preprocessing - Catagorical data mapping

# %%
df_categorical_map = df_drop_id.copy() # Checkpoint

# %%
catagorical_features = df_categorical_map.select_dtypes(include='object') # Obtain all categorical columns
print(catagorical_features.shape)
catagorical_features.head()
# Out:
# (202, 10)
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        fwd          front        ohc           four       mpfi
# 4        4wd          front        ohc           five       mpfi

# %%
encoder = ce.OrdinalEncoder(cols=catagorical_features) # Using Ordinal encoder
# encoder = ce.OneHotEncoder(cols=catagorical_features) # Using One Hot econder
encoded_features = encoder.fit_transform(df_categorical_map)
encoded_features.head()
# Out:
#    symboling  CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3        1         1           1           1        1           1
# 1          3        2         1           1           1        1           1
# 2          1        3         1           1           1        2           1
# 3          2        4         1           1           2        3           2
# 4          2        5         1           1           2        3           3
#
#    enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0               1       88.6      168.8  ...         130           1
# 1               1       88.6      168.8  ...         130           1
# 2               1       94.5      171.2  ...         152           1
# 3               1       99.8      176.6  ...         109           1
# 4               1       99.4      176.6  ...         136           1
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %% [markdown]
# ## Data Preprocessing - Scaling

# %%
from sklearn.preprocessing import StandardScaler

# Scaling data so all features have similar importance numerically
df_scaled = encoded_features.copy()
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_scaled)
df_scaled = pd.DataFrame(data=df_scaled, columns=encoded_features.columns)
df_scaled.head()
# Out:
#    symboling   CarName  fueltype  aspiration  doornumber   carbody  \
# 0   1.728635 -1.852824 -0.331497   -0.473542   -1.138180 -2.163384
# 1   1.728635 -1.828028 -0.331497   -0.473542   -1.138180 -2.163384
# 2   0.126872 -1.803232 -0.331497   -0.473542   -1.138180 -0.952848
# 3   0.927754 -1.778436 -0.331497   -0.473542    0.878595  0.257688
# 4   0.927754 -1.753640 -0.331497   -0.473542    0.878595  0.257688
#
#    drivewheel  enginelocation  wheelbase  carlength  ...  enginesize  \
# 0   -1.235892       -0.122782  -1.728891  -0.406622  ...    0.141131
# 1   -1.235892       -0.122782  -1.728891  -0.406622  ...    0.141131
# 2   -1.235892       -0.122782  -0.704535  -0.205755  ...    0.730040
# 3    0.573168       -0.122782   0.215649   0.246194  ...   -0.421009
# 4    2.382228       -0.122782   0.146202   0.246194  ...    0.301743
#
#    fuelsystem  boreratio    stroke  compressionratio  horsepower   peakrpm  \
# ...

# %% [markdown]
# ## Data Preprocessing - Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_scaled.drop(['price'], axis=1) # Drop target column to obtain just features
y = df_scaled['price']
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=.80, random_state=42) # 80/20 split
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(x_test.shape)
# Out:
# (161, 24)
# (161,)
# (41, 24)
# (41, 24)

# %% [markdown]
# ## Data Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train, y_train)
# Out:
# 0.9134934066920726

# %%
model.score(x_test, y_test)
# Out:
# 0.8679135876903227
